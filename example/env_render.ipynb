# %% [markdown]
# # This is a notebook to test rendering OpenAI Gym environments on Windows

# %%
import math

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pyvirtualdisplay
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\miniconda3\envs\research\lib\site-packages\easyprocess\__init__.py in start(self)
#     168             self.popen = subprocess.Popen(
# --> 169                 cmd, stdout=stdout, stderr=stderr, cwd=self.cwd, env=self.env,
#     170             )
#
# ~\miniconda3\envs\research\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
import gym

# %% [markdown]
# ## Show available envrionments

# %%
gym.envs.registry.all()
# Out:
# dict_values([EnvSpec(Copy-v0), EnvSpec(RepeatCopy-v0), EnvSpec(ReversedAddition-v0), EnvSpec(ReversedAddition3-v0), EnvSpec(DuplicatedInput-v0), EnvSpec(Reverse-v0), EnvSpec(CartPole-v0), EnvSpec(CartPole-v1), EnvSpec(MountainCar-v0), EnvSpec(MountainCarContinuous-v0), EnvSpec(Pendulum-v0), EnvSpec(Acrobot-v1), EnvSpec(LunarLander-v2), EnvSpec(LunarLanderContinuous-v2), EnvSpec(BipedalWalker-v3), EnvSpec(BipedalWalkerHardcore-v3), EnvSpec(CarRacing-v0), EnvSpec(Blackjack-v0), EnvSpec(KellyCoinflip-v0), EnvSpec(KellyCoinflipGeneralized-v0), EnvSpec(FrozenLake-v0), EnvSpec(FrozenLake8x8-v0), EnvSpec(CliffWalking-v0), EnvSpec(NChain-v0), EnvSpec(Roulette-v0), EnvSpec(Taxi-v3), EnvSpec(GuessingGame-v0), EnvSpec(HotterColder-v0), EnvSpec(Reacher-v2), EnvSpec(Pusher-v2), EnvSpec(Thrower-v2), EnvSpec(Striker-v2), EnvSpec(InvertedPendulum-v2), EnvSpec(InvertedDoublePendulum-v2), EnvSpec(HalfCheetah-v2), EnvSpec(HalfCheetah-v3), EnvSpec(Hopper-v2), EnvSpec(Hopper-v3), EnvSpec(Swimmer-v2), Env
# ...

# %%
def plot_environment(env, title='', figsize=(5,4)):
    plt.figure(figsize=figsize)
    img = env.render(mode="rgb_array")
    plt.imshow(img)
    plt.axis("off")
    plt.title(title)
    return img

# %%
def plot_env_list(names, nrows=1, figsize=(14, 6)):
    n = len(names)
    ncols = math.ceil(n / nrows)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    for name, ax in zip(names, axes.flatten()):
        env = gym.make(name)
        obs = env.reset()
        assert env.render() 
        img = env.render(mode="rgb_array")
        ax.imshow(img)
        ax.set_title(name)
    return fig

# %% [markdown]
# ## Render some environments

# %%
fig = plot_env_list(['CartPole-v1', 'MountainCar-v0', 'Pendulum-v0'], nrows=1, figsize=(14,8))
# Out:
# Exception ignored in: <function Viewer.__del__ at 0x00000259D6A73168>
# Traceback (most recent call last):
#   File "C:\Users\jian0\miniconda3\envs\research\lib\site-packages\gym\envs\classic_control\rendering.py", line 165, in __del__
#     self.close()
#   File "C:\Users\jian0\miniconda3\envs\research\lib\site-packages\gym\envs\classic_control\rendering.py", line 83, in close
#     self.window.close()
#   File "C:\Users\jian0\miniconda3\envs\research\lib\site-packages\pyglet\window\win32\__init__.py", line 299, in close
#     super(Win32Window, self).close()
#   File "C:\Users\jian0\miniconda3\envs\research\lib\site-packages\pyglet\window\__init__.py", line 823, in close
#     app.windows.remove(self)
#   File "C:\Users\jian0\miniconda3\envs\research\lib\_weakrefset.py", line 109, in remove
#     self.data.remove(ref(item))
# KeyError: (<weakref at 0x00000259E3A72688; to 'Win32Window' at 0x00000259D698B708>,)
# Exception ignored in: <function Viewer.__del__ at 0x00000259D6A73168>
# ...

# %%
fig = plot_env_list(['CartPole-v1', 'MountainCar-v0', 'Pendulum-v0', 
                     'LunarLander-v2', 'Freeway-v4', 'CarRacing-v0'], nrows=2, figsize=(14,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d06093160958> in <module>
#       1 fig = plot_env_list(['CartPole-v1', 'MountainCar-v0', 'Pendulum-v0',
# ----> 2                      'LunarLander-v2', 'Freeway-v4', 'CarRacing-v0'], nrows=2, figsize=(14,8))
#
# <ipython-input-6-1f0ca0e0a421> in plot_env_list(names, nrows, figsize)
#       4     fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
#       5     for name, ax in zip(names, axes.flatten()):
# ----> 6         env = gym.make(name)
#       7         obs = env.reset()
#       8         assert env.render()
#
# ~\miniconda3\envs\research\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     143
#     144 def make(id, **kwargs):
# --> 145     return registry.make(id, **kwargs)
#     146
#     147 def spec(id):
#
# ...
